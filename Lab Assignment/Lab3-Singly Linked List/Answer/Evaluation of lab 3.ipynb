# %%
import numpy as np

# %%
def printArray(givenArray):
  rows, columns = givenArray.shape
  for row in range(rows):
    for column in range(columns):
      print (givenArray[row][column], end = " ")
    print()

# %%
def synthesize_sequence(given_sequence):

    row, col = given_sequence.shape
    new = np.zeros(given_sequence.shape, dtype=str)

    for r in range (row):
      for c in range (col-1,0,-1):
        # print(given_sequence[r][col-1])
        temp=given_sequence[r][col-1]
        new[r][c]=given_sequence[r][c-1]
      new[r][0]=temp

    return new


# Driver code
given_sequence = np.array([['A', 'C', 'G', 'G'],['T', 'G', 'A', 'A'], ['G', 'G', 'A', 'C'], ['C', 'T', 'G', 'A']])
print("Original Array")
printArray(given_sequence)
print("=====================")
synthesizedArray1 = synthesize_sequence(given_sequence)
print("After Synthesizing")
printArray(synthesizedArray1)
print("=====================")

given_sequence = np.array([['A', 'C', 'G', 'G'], ['T', 'G', 'A', 'A'], ['A', 'G', 'A', 'C'],['A', 'T', 'G', 'A']])
print("Original Array")
printArray(given_sequence)
print("=====================")
synthesizedArray2 = synthesize_sequence(given_sequence)
print("After Synthesizing")
printArray(synthesizedArray2)
print("=====================")
# Out:
# Original Array
# A C G G
# T G A A
# G G A C
# C T G A
# =====================
# After Synthesizing
# G A C G
# A T G A
# C G G A
# A C T G
# =====================
# Original Array
# A C G G
# T G A A
# A G A C
# A T G A
# =====================
# After Synthesizing
# G A C G
# A T G A
# C A G A
# A A T G
# =====================

# %%
given_sequence = np.array(['A', 'C', 'G', 'G'])
# row,col=given_sequence.shape
for c in range
