# %%
import numpy as np
def mean(arr):
  sum=0
  for i in range (len(arr)):
    sum+=arr[i]
  mean_value=sum/len(arr)
  return mean_value

def standard_deviation(arr,m):
  sum_sq=0
  for i in range (len(arr)):
    sum_sq+=(arr[i]-m)**2
  std_dev=sum_sq/(len(arr)-1)
  std_dev=std_dev**(.5)
  return std_dev

def new(arr,m,stv):
  right_point=m+1.5*stv
  left_point=m-1.5*stv
  print(left_point)
  print(right_point)
  for i in range(len(arr)):
    a=[]
    if left_point<arr[i]<right_point:
      a.append(arr[i])
      print(a)
    rahi=np.array(a)
    return rahi

print("The mean of the numbers is:",end=" ")
print(mean([10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4]))

print("The standard deviation is:",end=' ')
print(standard_deviation([10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4],10.181818181818))
print(new([10, 8, 13, 9, 14, 25, -5, 20, 7, 7, 4],10.181818181818,7.96))
# Out:
# The mean of the numbers is: 10.181818181818182
# The standard deviation is: 7.960127911260996
# -1.758181818181999
# 22.121818181818
# [10]
# [10]
